# %% [markdown]
# <a href="https://colab.research.google.com/github/thiru-bit/COMP-690-Deep-Learning/blob/main/11_2_residual_networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-jn0hh587
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-jn0hh587
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    # First layer (no residual)
    h1 = self.linear1(x).relu()

    # First residual block
    h2 = self.linear2(h1).relu()
    h2 = h1 + h2   # skip connection

    # Second residual block
    h3 = self.linear3(h2).relu()
    h3 = h2 + h3   # skip connection

    # Output layer
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.658002, train error 64.55,  val loss 1.755884, percent error 70.30
# Epoch     1, train loss 1.407548, train error 53.78,  val loss 1.543080, percent error 62.00
# Epoch     2, train loss 1.172160, train error 42.70,  val loss 1.335741, percent error 52.60
# Epoch     3, train loss 1.066233, train error 39.40,  val loss 1.278023, percent error 49.50
# Epoch     4, train loss 0.943888, train error 33.82,  val loss 1.189688, percent error 45.70
# Epoch     5, train loss 0.817565, train error 28.75,  val loss 1.110136, percent error 43.40
# Epoch     6, train loss 0.750618, train error 25.85,  val loss 1.099099, percent error 42.40
# Epoch     7, train loss 0.712399, train error 25.82,  val loss 1.115957, percent error 40.60
# Epoch     8, train loss 0.627627, train error 21.72,  val loss 1.074535, percent error 39.70
# Epoch     9, train loss 0.556611, train error 19.22,  val loss 1.115996, percent error 41.00
# Epoch    10, train loss 0.501549, train error 16.60,  val loss 1.104686, percent error 42.10
# Epoch    11, train loss 0.504011, train error 18.50,  val loss 1.185214, percent error 41.60
# Epoch    12, train loss 0.404698, train error 13.78,  val loss 1.119427, percent error 38.90
# Epoch    13, train loss 0.374279, train error 13.28,  val loss 1.208881, percent error 39.90
# Epoch    14, train loss 0.354812, train error 12.45,  val loss 1.273986, percent error 40.10
# Epoch    15, train loss 0.292147, train error 9.45,  val loss 1.220676, percent error 36.50
# Epoch    16, train loss 0.271646, train error 9.05,  val loss 1.240357, percent error 38.10
# Epoch    17, train loss 0.262142, train error 8.55,  val loss 1.333844, percent error 38.80
# Epoch    18, train loss 0.205341, train error 6.10,  val loss 1.338191, percent error 38.30
# Epoch    19, train loss 0.205981, train error 7.15,  val loss 1.429142, percent error 38.50
# Epoch    20, train loss 0.080576, train error 0.93,  val loss 1.276890, percent error 36.30
# Epoch    21, train loss 0.058850, train error 0.35,  val loss 1.252342, percent error 34.00
# Epoch    22, train loss 0.045788, train error 0.03,  val loss 1.276698, percent error 34.70
# Epoch    23, train loss 0.042771, train error 0.15,  val loss 1.312921, percent error 33.70
# Epoch    24, train loss 0.034388, train error 0.00,  val loss 1.325464, percent error 34.70
# Epoch    25, train loss 0.029356, train error 0.00,  val loss 1.353096, percent error 34.60
# Epoch    26, train loss 0.025827, train error 0.00,  val loss 1.367332, percent error 34.60
# Epoch    27, train loss 0.023409, train error 0.00,  val loss 1.378082, percent error 33.70
# Epoch    28, train loss 0.021121, train error 0.00,  val loss 1.400803, percent error 33.70
# Epoch    29, train loss 0.019210, train error 0.00,  val loss 1.414550, percent error 34.90
# Epoch    30, train loss 0.017481, train error 0.00,  val loss 1.433865, percent error 34.20
# Epoch    31, train loss 0.016175, train error 0.00,  val loss 1.441572, percent error 34.20
# Epoch    32, train loss 0.015032, train error 0.00,  val loss 1.461853, percent error 34.20
# Epoch    33, train loss 0.014067, train error 0.00,  val loss 1.474659, percent error 34.50
# Epoch    34, train loss 0.013115, train error 0.00,  val loss 1.490825, percent error 34.30
# Epoch    35, train loss 0.012516, train error 0.00,  val loss 1.505842, percent error 34.90
# Epoch    36, train loss 0.011560, train error 0.00,  val loss 1.515852, percent error 34.00
# Epoch    37, train loss 0.010944, train error 0.00,  val loss 1.524389, percent error 34.10
# Epoch    38, train loss 0.010339, train error 0.00,  val loss 1.537150, percent error 34.20
# Epoch    39, train loss 0.009865, train error 0.00,  val loss 1.547392, percent error 34.00
# Epoch    40, train loss 0.009557, train error 0.00,  val loss 1.552877, percent error 33.70
# Epoch    41, train loss 0.009313, train error 0.00,  val loss 1.558469, percent error 34.20
# Epoch    42, train loss 0.009085, train error 0.00,  val loss 1.562196, percent error 34.00
# Epoch    43, train loss 0.008907, train error 0.00,  val loss 1.566365, percent error 34.10
# Epoch    44, train loss 0.008697, train error 0.00,  val loss 1.572995, percent error 34.30
# Epoch    45, train loss 0.008524, train error 0.00,  val loss 1.579324, percent error 34.10
# Epoch    46, train loss 0.008318, train error 0.00,  val loss 1.582311, percent error 33.90
# Epoch    47, train loss 0.008148, train error 0.00,  val loss 1.587828, percent error 34.50
# Epoch    48, train loss 0.007977, train error 0.00,  val loss 1.590001, percent error 34.00
# Epoch    49, train loss 0.007828, train error 0.00,  val loss 1.595878, percent error 34.10
# Epoch    50, train loss 0.007652, train error 0.00,  val loss 1.601462, percent error 34.10
# Epoch    51, train loss 0.007513, train error 0.00,  val loss 1.605214, percent error 34.00
# Epoch    52, train loss 0.007367, train error 0.00,  val loss 1.610803, percent error 33.80
# Epoch    53, train loss 0.007221, train error 0.00,  val loss 1.615983, percent error 34.20
# Epoch    54, train loss 0.007084, train error 0.00,  val loss 1.618873, percent error 34.20
# Epoch    55, train loss 0.006955, train error 0.00,  val loss 1.624133, percent error 34.20
# Epoch    56, train loss 0.006840, train error 0.00,  val loss 1.625088, percent error 34.40
# Epoch    57, train loss 0.006706, train error 0.00,  val loss 1.629294, percent error 34.40
# Epoch    58, train loss 0.006580, train error 0.00,  val loss 1.635051, percent error 34.10
# Epoch    59, train loss 0.006470, train error 0.00,  val loss 1.640156, percent error 34.20
# Epoch    60, train loss 0.006404, train error 0.00,  val loss 1.641051, percent error 34.30
# Epoch    61, train loss 0.006348, train error 0.00,  val loss 1.642501, percent error 34.30
# Epoch    62, train loss 0.006292, train error 0.00,  val loss 1.644412, percent error 34.20
# Epoch    63, train loss 0.006240, train error 0.00,  val loss 1.647066, percent error 34.30
# Epoch    64, train loss 0.006186, train error 0.00,  val loss 1.648052, percent error 34.40
# Epoch    65, train loss 0.006134, train error 0.00,  val loss 1.650284, percent error 34.20
# Epoch    66, train loss 0.006085, train error 0.00,  val loss 1.651460, percent error 34.30
# Epoch    67, train loss 0.006033, train error 0.00,  val loss 1.653606, percent error 34.20
# Epoch    68, train loss 0.005985, train error 0.00,  val loss 1.655362, percent error 34.40
# Epoch    69, train loss 0.005937, train error 0.00,  val loss 1.656994, percent error 34.30
# Epoch    70, train loss 0.005888, train error 0.00,  val loss 1.658924, percent error 34.30
# Epoch    71, train loss 0.005841, train error 0.00,  val loss 1.659837, percent error 34.20
# Epoch    72, train loss 0.005796, train error 0.00,  val loss 1.661938, percent error 34.30
# Epoch    73, train loss 0.005750, train error 0.00,  val loss 1.664046, percent error 34.20
# Epoch    74, train loss 0.005707, train error 0.00,  val loss 1.665098, percent error 34.30
# Epoch    75, train loss 0.005660, train error 0.00,  val loss 1.667249, percent error 34.30
# Epoch    76, train loss 0.005616, train error 0.00,  val loss 1.668425, percent error 34.30
# Epoch    77, train loss 0.005574, train error 0.00,  val loss 1.670666, percent error 34.30
# Epoch    78, train loss 0.005531, train error 0.00,  val loss 1.672439, percent error 34.30
# Epoch    79, train loss 0.005487, train error 0.00,  val loss 1.674754, percent error 34.20
# Epoch    80, train loss 0.005466, train error 0.00,  val loss 1.675297, percent error 34.20
# Epoch    81, train loss 0.005445, train error 0.00,  val loss 1.676076, percent error 34.10
# Epoch    82, train loss 0.005425, train error 0.00,  val loss 1.676733, percent error 34.20
# Epoch    83, train loss 0.005404, train error 0.00,  val loss 1.677647, percent error 34.20
# Epoch    84, train loss 0.005384, train error 0.00,  val loss 1.678416, percent error 34.30
# Epoch    85, train loss 0.005364, train error 0.00,  val loss 1.679344, percent error 34.10
# Epoch    86, train loss 0.005344, train error 0.00,  val loss 1.680163, percent error 34.20
# Epoch    87, train loss 0.005324, train error 0.00,  val loss 1.680945, percent error 34.20
# Epoch    88, train loss 0.005305, train error 0.00,  val loss 1.681721, percent error 34.20
# Epoch    89, train loss 0.005285, train error 0.00,  val loss 1.682475, percent error 34.20
# Epoch    90, train loss 0.005266, train error 0.00,  val loss 1.683407, percent error 34.20
# Epoch    91, train loss 0.005246, train error 0.00,  val loss 1.684303, percent error 34.30
# Epoch    92, train loss 0.005227, train error 0.00,  val loss 1.685035, percent error 34.10
# Epoch    93, train loss 0.005208, train error 0.00,  val loss 1.685813, percent error 34.30
# Epoch    94, train loss 0.005189, train error 0.00,  val loss 1.686779, percent error 34.10
# Epoch    95, train loss 0.005171, train error 0.00,  val loss 1.687567, percent error 34.10
# Epoch    96, train loss 0.005152, train error 0.00,  val loss 1.688008, percent error 34.30
# Epoch    97, train loss 0.005133, train error 0.00,  val loss 1.689280, percent error 34.30
# Epoch    98, train loss 0.005115, train error 0.00,  val loss 1.689548, percent error 34.20
# Epoch    99, train loss 0.005097, train error 0.00,  val loss 1.690460, percent error 34.20

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
